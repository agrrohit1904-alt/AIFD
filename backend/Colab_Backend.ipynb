# %% [markdown]
# # Identity Verification Backend (SIH Hackathon)
# This notebook runs the heavy Deep Learning FastAPI backend for free using Google Colab's 12GB RAM servers!

# %%
import os
# !apt-get update
# !apt-get install -y tesseract-ocr libzbar0 zbar-tools

# Clone repo safely
if not os.path.exists('/content/AIFD'):
    # !git clone https://github.com/agrrohit1904-alt/AIFD.git /content/AIFD
else:
    # %cd /content/AIFD
    # !git pull origin main

# %cd /content/AIFD/backend
# !pip install -r requirements.txt

# %%
import os
import time

# Force working directory to backend so Uvicorn can find the app
# %cd /content/AIFD/backend

# Download Cloudflare Tunnel
# !wget -q -c -nc https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64

# Start the FastAPI server in the background and save logs to uvicorn.log
print("Starting FastAPI server...")
# !nohup python -m uvicorn app.main:app --host 0.0.0.0 --port 8000 > uvicorn.log 2>&1 &

time.sleep(4) # Wait for server to start

# Start Cloudflare Tunnel in the foreground so we can see all the raw output!
print("Starting Cloudflare Tunnel...")
print("\nIf you get connection refused, run a new cell with: !cat uvicorn.log to see the error!\n")
# !./cloudflared-linux-amd64 tunnel --url http://127.0.0.1:8000
