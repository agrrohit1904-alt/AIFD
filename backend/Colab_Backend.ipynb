# %% [markdown]
# # Identity Verification Backend (SIH Hackathon)
# This notebook runs the heavy Deep Learning FastAPI backend for free using Google Colab's 12GB RAM servers!

# %%
# !apt-get update
# !apt-get install -y tesseract-ocr libzbar0 zbar-tools
# !git clone https://github.com/agrrohit1904-alt/AIFD.git
# %cd AIFD/backend
# !pip install -r requirements.txt
# !npm install -g localtunnel

# %%
import urllib.request
print("=========================================")
print("PASSWORD FOR LOCALTUNNEL:", urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip())
print("=========================================")

# Run the FastAPI server in the background and expose it using localtunnel
# !uvicorn app.main:app --host 0.0.0.0 --port 8000 & npx localtunnel --port 8000
